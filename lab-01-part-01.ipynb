# %% [markdown]
# <!--# <img style="float: left; padding-right: 10px; width: 200px" src="https://raw.githubusercontent.com/trivikverma/researchgroup/master/assets/media/logo.png"> EPA-122A *Spatial* Data Science -->
#
#
# ## Lab 1 - part 1: Data, Grammar and Engineering (Pandas)
#
# **AMS MADE YMS31303**<br>
# **Q1 2024**<br>
# **Instructor:** Theodoros Chatzivasileiadis <br>
# **Instructor:** Hans Hoogenboom <br>
# **TA:** Ka Yi Chua <br>
# **[Metropolitan Data 1](https://jhoogenboom.github.io/spatial-data-science/_index.html)** <br>
#
# ---

# %% [markdown]
# ## Table of Contents
#
# * [Learning Goals](#section0)
# * [Data Munging](#section1)
#     * [Dataset](#section_1_1)
#     * [Data, Sliced and Diced](#section_1_2)
# * [Visual Exploration](#section2)
#     * [Histogram](#section_2_1)
#     * [Kernel Density Plots](#section_2_2)
#     * [Line and Bar Plots](#section_2_3)
# * [(Un)tidy Data](#section3)
#     * [Grouping, transforming, aggregating](#section_3_1)

# %% [markdown]
# ## Learning Goals <a class="anchor" id="section0"></a>
#
# - Obtain the basic tools to manipulate, investigate and visualise the data.
# - Understand the concept of tidy/untidy data and how to prepare the data.
#
# This notebook covers the basic tools of data analysis that are **needed** for the course.

# %% [markdown]
# ## Data Munging <a class="anchor" id="section1"></a>
#
# Real world datasets are messy. There is no way around it: datasets have "holes" (missing data), the amount of formats in which data can be stored is endless, and the best structure to share data is not always the optimum to analyze them, hence the need to [munge](https://dictionary.reference.com/browse/munge) them. As has been correctly pointed out in many outlets ([e.g.](https://www.nytimes.com/2014/08/18/technology/for-big-data-scientists-hurdle-to-insights-is-janitor-work.html?_r=0)), much of the time [spent](https://twitter.com/BigDataBorat/status/306596352991830016) in what is called (Geo-)Data Science is related not only to sophisticated modeling and insight, but has to do with much more basic and less exotic tasks such as obtaining data, processing, turning them into a shape that makes analysis possible, and exploring it to get to know their basic properties.
#
# For how labor intensive and relevant this aspect is, there is surprisingly very little published on patterns, techniques, and best practices for quick and efficient data cleaning, manipulation, and transformation. In this session, you will use a few real world datasets and learn how to process them into Python so they can be transformed and manipulated, if necessary, and analyzed. For this, we will introduce some of the bread and butter of data analysis and scientific computing in Python. These are fundamental tools that are constantly used in almost any task relating to data analysis.
#
# This notebook covers the basic and the content that is expected to be learnt by every student. We use a prepared dataset that saves us much of the more intricate processing that goes beyond the introductory level the session is aimed at. As a companion to this introduction, there is an additional notebook (see link on the website page for Lab 01) that covers how the dataset used here was prepared from raw data downloaded from the internet, and includes some additional exercises you can do if you want dig deeper into the content of this lab.
#
# In this notebook, we discuss several patterns to clean and structure data properly, including tidying, subsetting, and aggregating; and we finish with some basic visualization. An additional extension presents more advanced tricks to manipulate tabular data.
#
# Before we get our hands data-dirty, let us import all the additional libraries we will need, so we can get that out of the way and focus on the task at hand:

# %%
# This ensures visualizations are plotted inside the notebook
# %matplotlib inline
import matplotlib
import os              # This provides several system utilities
import pandas as pd    # This is the workhorse of data munging in Python
import numpy as np     # This is for general numerical operations 
import seaborn as sns  # This allows us to efficiently and beautifully plot
import os              # This provides several system utilities

# %% [markdown]
# ### Dataset <a class="anchor" id="section_1_1"></a>
#
# We will be exploring some of the characteristics of the population in The Hague. To do that, we will use a dataset that contains population counts, split by ethnic origin: https://denhaag.incijfers.nl/jive. Let us first set the path to the file where we store the data we will use:

# %%
# Important! You need to specify the path to the data in *your* machine
# If you have placed the data folder in the same directory as this notebook,
# you would do:

f = 'data/DenHaag'                   # Path to file containing the table

# Check to see if the path is correct and works. If you have set it 
# correctly, you should obtain the following list
os.listdir(f)
# Out:
# ['DenHaag_.csv',
#  'DenHaag_short.csv',
#  'Den_Haag_long.csv',
#  'neighborhoods.cpg',
#  'neighborhoods.dbf',
#  'neighborhoods.json',
#  'neighborhoods.prj',
#  'neighborhoods.shp',
#  'neighborhoods.shx']

# %% [markdown]
# **IMPORTANT**: the path above might look different in your computer.

# %% [markdown]
# To read a "comma separated values" (`.csv`) file, we can run:

# %%
# We are going to work with DenHaag_.csv. Let's adjust the path:
f = 'data/DenHaag/DenHaag_.csv'
db = pd.read_csv(f, index_col='Buurten')    # Read the table in

# %% [markdown]
# Let us stop for a minute to learn how we have read the file. Here are the main aspects to keep in mind:
#
# * We are using the method `read_csv` from the `pandas` library, which we have imported with the alias `pd`.
# * In this form, all that is required is to pass the path to the file we want to read, which in this case we have created by concatenating two strings. We can see the full path we have used:

# %%
f
# Out:
# 'data/DenHaag/DenHaag_.csv'

# %% [markdown]
# * the `sep` argument defines the seperator. It is default set to `,` which is also the standard deperator in a csv file. In our case the dataset is seperated by `;` however.
# * The argument `index_col` is not strictly necessary but allows us to choose one of the columns as the index of the table. More on indices below.
# * We are using `read_csv` because the file we want to read is in the `csv` format. However, `pandas` allows for many more formats to be read (and written, just replace `read` by `to`! For example, `read_csv` reads in, `to_csv` writes out). A full list of formats supported may be found [here](https://pandas.pydata.org/pandas-docs/version/0.18.1/io.html).
#
# ### Data, Sliced and Diced <a class="anchor" id="section_1_2"></a>
#
# Now we are ready to start playing and interrogating the dataset! What we have at our fingertips is a table that summarizes, for each of the buurtens in The Hague, how many people live in each, by the region of the world where they were born. Now, let us learn a few cool tricks built into `pandas` that work out-of-the box with a table like ours.
#
# * Inspecting what it looks like. We can check the top (bottom) X lines of the table by passing X to the method `head` (`tail`). For example, for the top/bottom five lines:

# %%
db.head(2)
# Out:
#                      Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                        2983.0              151.0
# 02 Vissershaven                            4416.0              195.0
#
#                      5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 01 Oud Scheveningen               272.0                115.0
# 02 Vissershaven                   466.0                219.0
#
#                      20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 01 Oud Scheveningen               1035.0                855.0
# 02 Vissershaven                   1492.0               1185.0
#
#                      65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 01 Oud Scheveningen                433.0                  122.0
# 02 Vissershaven                    701.0                  158.0
#
#                      % Nederlands|2023  % Turks|2023  % Marokkaans|2023  \
# Buurten
# 01 Oud Scheveningen               71.8           0.6                1.0
# 02 Vissershaven                   66.3           1.2                1.4
#
#                      % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 01 Oud Scheveningen               1.4                 1.1
# 02 Vissershaven                   2.4                 1.0
#
#                      % Overig niet-westers|2023  % Westers|2023
# Buurten
# 01 Oud Scheveningen                         6.9            17.2
# 02 Vissershaven                             7.7            20.0

# %%
db.tail()
# Out:
#                  Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 117 De Rivieren                          24.0                NaN
# 118 De Lanen                           5368.0              272.0
# 119 De Velden                          4162.0              145.0
# 120 De Vissen                          8346.0              350.0
# 121 Rietbuurt                          2758.0              145.0
#
#                  5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  20 t/m 44 jaar|2023  \
# Buurten
# 117 De Rivieren                 NaN                  NaN                  5.0
# 118 De Lanen                  973.0                500.0               1655.0
# 119 De Velden                 528.0                344.0               1148.0
# 120 De Vissen                 998.0                704.0               2077.0
# 121 Rietbuurt                 660.0                184.0                873.0
#
#                  45 t/m 64 jaar|2023  65 t/m 79 jaar|2023  \
# Buurten
# 117 De Rivieren                 13.0                  NaN
# 118 De Lanen                  1657.0                276.0
# 119 De Velden                 1427.0                491.0
# 120 De Vissen                 2929.0                998.0
# 121 Rietbuurt                  742.0                137.0
#
#                  80 jaar en ouder|2023  % Nederlands|2023  % Turks|2023  \
# Buurten
# 117 De Rivieren                    NaN              100.0           NaN
# 118 De Lanen                      35.0               49.6           4.2
# 119 De Velden                     79.0               55.0           4.0
# 120 De Vissen                    290.0               58.3           2.6
# 121 Rietbuurt                     17.0               47.7           4.6
#
#                  % Marokkaans|2023  % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 117 De Rivieren                NaN               NaN                 NaN
# 118 De Lanen                   4.2              11.6                 2.9
# 119 De Velden                  4.6              10.3                 1.1
# 120 De Vissen                  4.0              11.5                 1.7
# 121 Rietbuurt                  7.7              10.8                 1.9
#
#                  % Overig niet-westers|2023  % Westers|2023
# Buurten
# 117 De Rivieren                         NaN             NaN
# 118 De Lanen                           16.0            11.5
# 119 De Velden                          14.6            10.4
# 120 De Vissen                          10.7            11.2
# 121 Rietbuurt                          15.4            11.8

# %% [markdown]
# - Now lets get an overview of data types

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114 entries, 01 Oud Scheveningen to 121 Rietbuurt
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Aantal inwoners per 1-1|2023  111 non-null    float64
#  1   0 t/m 4 jaar|2023             107 non-null    float64
#  2   5 t/m 14 jaar|2023            107 non-null    float64
#  3   15 t/m 19 jaar|2023           107 non-null    float64
#  4   20 t/m 44 jaar|2023           110 non-null    float64
#  5   45 t/m 64 jaar|2023           111 non-null    float64
#  6   65 t/m 79 jaar|2023           110 non-null    float64
#  7   80 jaar en ouder|2023         107 non-null    float64
#  8   % Nederlands|2023             111 non-null    float64
#  9   % Turks|2023                  103 non-null    float64
#  10  % Marokkaans|2023             95 non-null     float64
#  11  % Surinaams|2023              104 non-null    float64
#  12  % Antilliaans|2023            102 non-null    float64
#  13  % Overig niet-westers|2023    109 non-null    float64
#  14  % Westers|2023                110 non-null    float64
# dtypes: float64(15)
# memory usage: 14.2+ KB

# %%
db.describe()
# Out:
#        Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  5 t/m 14 jaar|2023  \
# count                    111.000000         107.000000          107.000000
# mean                    5073.171171         268.943925          574.616822
# std                     3365.942907         189.016363          393.491067
# min                       24.000000          10.000000            6.000000
# 25%                     2386.500000         118.500000          257.000000
# 50%                     4744.000000         245.000000          528.000000
# 75%                     7237.500000         399.000000          845.500000
# max                    16749.000000         889.000000         1738.000000
#
#        15 t/m 19 jaar|2023  20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# count           107.000000           110.000000           111.000000
# mean            302.934579          1914.481818          1308.882883
# std             213.279083          1474.818973           861.831124
# min               8.000000             5.000000            13.000000
# 25%             110.500000           714.500000           644.000000
# 50%             285.000000          1640.000000          1205.000000
# 75%             442.000000          2835.750000          1866.500000
# max             989.000000          6768.000000          4004.000000
#
#        65 t/m 79 jaar|2023  80 jaar en ouder|2023  % Nederlands|2023  \
# count           110.000000             107.000000         111.000000
# mean            589.663636             183.934579          46.553153
# std             406.969022             154.038483          20.036666
# min               5.000000               5.000000           5.800000
# 25%             316.500000              80.000000          27.900000
# 50%             498.000000             144.000000          49.600000
# 75%             799.750000             225.500000          61.250000
# max            2343.000000             750.000000         100.000000
#
#        % Turks|2023  % Marokkaans|2023  % Surinaams|2023  % Antilliaans|2023  \
# count    103.000000          95.000000        104.000000          102.000000
# mean       6.464078           5.271579          7.153846            2.480392
# std        7.530967           5.309900          5.091472            2.011110
# min        0.300000           0.100000          0.500000            0.300000
# 25%        1.050000           1.100000          2.200000            1.100000
# 50%        3.000000           3.900000          6.700000            1.850000
# 75%       10.000000           7.750000         11.525000            3.400000
# max       28.400000          24.700000         21.100000           11.700000
#
#        % Overig niet-westers|2023  % Westers|2023
# count                  109.000000      110.000000
# mean                    12.660550       21.500909
# std                      5.379695        8.391034
# min                      3.300000        7.300000
# 25%                      8.800000       13.975000
# 50%                     11.100000       20.750000
# 75%                     16.600000       27.025000
# max                     28.000000       40.800000

# %% [markdown]
# Note how the output is also a `DataFrame` object, so you can do with it the same things you would with the original table (e.g. writing it to a file). In this case, the summary might be better presented if the table is "transposed":

# %%
db.describe().T
# Out:
#                               count         mean          std   min       25%  \
# Aantal inwoners per 1-1|2023  111.0  5073.171171  3365.942907  24.0  2386.500
# 0 t/m 4 jaar|2023             107.0   268.943925   189.016363  10.0   118.500
# 5 t/m 14 jaar|2023            107.0   574.616822   393.491067   6.0   257.000
# 15 t/m 19 jaar|2023           107.0   302.934579   213.279083   8.0   110.500
# 20 t/m 44 jaar|2023           110.0  1914.481818  1474.818973   5.0   714.500
# 45 t/m 64 jaar|2023           111.0  1308.882883   861.831124  13.0   644.000
# 65 t/m 79 jaar|2023           110.0   589.663636   406.969022   5.0   316.500
# 80 jaar en ouder|2023         107.0   183.934579   154.038483   5.0    80.000
# % Nederlands|2023             111.0    46.553153    20.036666   5.8    27.900
# % Turks|2023                  103.0     6.464078     7.530967   0.3     1.050
# % Marokkaans|2023              95.0     5.271579     5.309900   0.1     1.100
# % Surinaams|2023              104.0     7.153846     5.091472   0.5     2.200
# % Antilliaans|2023            102.0     2.480392     2.011110   0.3     1.100
# % Overig niet-westers|2023    109.0    12.660550     5.379695   3.3     8.800
# % Westers|2023                110.0    21.500909     8.391034   7.3    13.975
#
#                                   50%       75%      max
# Aantal inwoners per 1-1|2023  4744.00  7237.500  16749.0
# 0 t/m 4 jaar|2023              245.00   399.000    889.0
# 5 t/m 14 jaar|2023             528.00   845.500   1738.0
# 15 t/m 19 jaar|2023            285.00   442.000    989.0
# 20 t/m 44 jaar|2023           1640.00  2835.750   6768.0
# 45 t/m 64 jaar|2023           1205.00  1866.500   4004.0
# 65 t/m 79 jaar|2023            498.00   799.750   2343.0
# 80 jaar en ouder|2023          144.00   225.500    750.0
# % Nederlands|2023               49.60    61.250    100.0
# % Turks|2023                     3.00    10.000     28.4
# % Marokkaans|2023                3.90     7.750     24.7
# % Surinaams|2023                 6.70    11.525     21.1
# % Antilliaans|2023               1.85     3.400     11.7
# % Overig niet-westers|2023      11.10    16.600     28.0
# % Westers|2023                  20.75    27.025     40.8

# %% [markdown]
# * Equally, common descriptive statistics are also available:

# %%
# Obtain minimum values for each table
db.min()
# Out:
# Aantal inwoners per 1-1|2023    24.0
# 0 t/m 4 jaar|2023               10.0
# 5 t/m 14 jaar|2023               6.0
# 15 t/m 19 jaar|2023              8.0
# 20 t/m 44 jaar|2023              5.0
# 45 t/m 64 jaar|2023             13.0
# 65 t/m 79 jaar|2023              5.0
# 80 jaar en ouder|2023            5.0
# % Nederlands|2023                5.8
# % Turks|2023                     0.3
# % Marokkaans|2023                0.1
# % Surinaams|2023                 0.5
# % Antilliaans|2023               0.3
# % Overig niet-westers|2023       3.3
# % Westers|2023                   7.3
# dtype: float64

# %%
# Obtain the minimum population share of Marokaans
db['% Marokkaans|2023'].min()
# Out:
# np.float64(0.1)

# %%
# Obtain standard deviation for the row `117 De Rivieren`, 
# Does this value have any informative value for us? 
db.loc['117 De Rivieren', :].std()
# Out:
# np.float64(43.699733027407234)

# %% [markdown]
# * Creation of new variables: we can generate new variables by applying operations on existing ones. For example, we can calculate the total population by area. Here is a couple of ways to do it:

# %%
# One shot
total = db.sum(axis=1)
# Print the top of the variable
total.head()
# Out:
# Buurten
# 01 Oud Scheveningen             6066.0
# 02 Vissershaven                 8932.0
# 03 Scheveningen Badplaats      11440.0
# 04 Visserijbuurt                8195.9
# 05 v Stolkpark/Schev Bosjes     1785.8
# dtype: float64

# %%
# Summing up a subsection of variables:
Non_Dutch = db['% Turks|2023'] + db['% Marokkaans|2023'] + db['% Surinaams|2023'] \
        + db['% Antilliaans|2023'] + db['% Overig niet-westers|2023'] + db['% Westers|2023']
# Print the top of the variable
Non_Dutch.head()
# Out:
# Buurten
# 01 Oud Scheveningen            28.2
# 02 Vissershaven                33.7
# 03 Scheveningen Badplaats      39.1
# 04 Visserijbuurt               38.9
# 05 v Stolkpark/Schev Bosjes    49.9
# dtype: float64

# %% [markdown]
# Note how we are using the command `sum`, just like we did with `max` or `min` before but, in this case, we are not applying it over columns (e.g. the max of each column), but over rows, so we get the total sum of populations by areas.
#
# Once we have created the variable, we can make it part of the table:

# %%
db['% Non-Dutch | 2023'] = Non_Dutch
db.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 db['% Non-Dutch | 2023'] = Non_Dutch
#       2 db.head()
#
# NameError: name 'Non_Dutch' is not defined

# %% [markdown]
# * Assigning new values: we can easily generate new variables with scalars, and modify those.

# %%
# New variable with all ones
db['ones'] = 1
db.head()
# Out:
#                              Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                                2983.0              151.0
# 02 Vissershaven                                    4416.0              195.0
# 03 Scheveningen Badplaats                          5670.0              262.0
# 04 Visserijbuurt                                   4048.0              178.0
# 05 v Stolkpark/Schev Bosjes                         843.0               29.0
#
#                              5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       272.0                115.0
# 02 Vissershaven                           466.0                219.0
# 03 Scheveningen Badplaats                 521.0                266.0
# 04 Visserijbuurt                          444.0                205.0
# 05 v Stolkpark/Schev Bosjes                75.0                 54.0
#
#                              20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       1035.0                855.0
# 02 Vissershaven                           1492.0               1185.0
# 03 Scheveningen Badplaats                 2113.0               1518.0
# 04 Visserijbuurt                          1343.0               1023.0
# 05 v Stolkpark/Schev Bosjes                204.0                254.0
#
#                              65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 01 Oud Scheveningen                        433.0                  122.0
# 02 Vissershaven                            701.0                  158.0
# 03 Scheveningen Badplaats                  788.0                  202.0
# 04 Visserijbuurt                           591.0                  264.0
# 05 v Stolkpark/Schev Bosjes                166.0                   61.0
#
#                              % Nederlands|2023  % Turks|2023  \
# Buurten
# 01 Oud Scheveningen                       71.8           0.6
# 02 Vissershaven                           66.3           1.2
# 03 Scheveningen Badplaats                 60.9           0.6
# 04 Visserijbuurt                          61.0           0.7
# 05 v Stolkpark/Schev Bosjes               49.9           0.8
#
#                              % Marokkaans|2023  % Surinaams|2023  \
# Buurten
# 01 Oud Scheveningen                        1.0               1.4
# 02 Vissershaven                            1.4               2.4
# 03 Scheveningen Badplaats                  0.4               1.8
# 04 Visserijbuurt                           1.6               1.9
# 05 v Stolkpark/Schev Bosjes                1.2               0.9
#
#                              % Antilliaans|2023  % Overig niet-westers|2023  \
# Buurten
# 01 Oud Scheveningen                         1.1                         6.9
# 02 Vissershaven                             1.0                         7.7
# 03 Scheveningen Badplaats                   1.1                         9.5
# 04 Visserijbuurt                            1.4                         9.8
# 05 v Stolkpark/Schev Bosjes                 1.3                         9.8
#
#                              % Westers|2023  twos  ones
# Buurten
# 01 Oud Scheveningen                    17.2     2     1
# 02 Vissershaven                        20.0     2     1
# 03 Scheveningen Badplaats              25.7     2     1
# 04 Visserijbuurt                       23.5     2     1
# 05 v Stolkpark/Schev Bosjes            35.9     2     1

# %% [markdown]
# And we can modify specific values too:

# %%
db.loc['03 Scheveningen Badplaats', 'ones'] = 3
db.head()
# Out:
#                              Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                                2983.0              151.0
# 02 Vissershaven                                    4416.0              195.0
# 03 Scheveningen Badplaats                          5670.0              262.0
# 04 Visserijbuurt                                   4048.0              178.0
# 05 v Stolkpark/Schev Bosjes                         843.0               29.0
#
#                              5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       272.0                115.0
# 02 Vissershaven                           466.0                219.0
# 03 Scheveningen Badplaats                 521.0                266.0
# 04 Visserijbuurt                          444.0                205.0
# 05 v Stolkpark/Schev Bosjes                75.0                 54.0
#
#                              20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       1035.0                855.0
# 02 Vissershaven                           1492.0               1185.0
# 03 Scheveningen Badplaats                 2113.0               1518.0
# 04 Visserijbuurt                          1343.0               1023.0
# 05 v Stolkpark/Schev Bosjes                204.0                254.0
#
#                              65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 01 Oud Scheveningen                        433.0                  122.0
# 02 Vissershaven                            701.0                  158.0
# 03 Scheveningen Badplaats                  788.0                  202.0
# 04 Visserijbuurt                           591.0                  264.0
# 05 v Stolkpark/Schev Bosjes                166.0                   61.0
#
#                              % Nederlands|2023  % Turks|2023  \
# Buurten
# 01 Oud Scheveningen                       71.8           0.6
# 02 Vissershaven                           66.3           1.2
# 03 Scheveningen Badplaats                 60.9           0.6
# 04 Visserijbuurt                          61.0           0.7
# 05 v Stolkpark/Schev Bosjes               49.9           0.8
#
#                              % Marokkaans|2023  % Surinaams|2023  \
# Buurten
# 01 Oud Scheveningen                        1.0               1.4
# 02 Vissershaven                            1.4               2.4
# 03 Scheveningen Badplaats                  0.4               1.8
# 04 Visserijbuurt                           1.6               1.9
# 05 v Stolkpark/Schev Bosjes                1.2               0.9
#
#                              % Antilliaans|2023  % Overig niet-westers|2023  \
# Buurten
# 01 Oud Scheveningen                         1.1                         6.9
# 02 Vissershaven                             1.0                         7.7
# 03 Scheveningen Badplaats                   1.1                         9.5
# 04 Visserijbuurt                            1.4                         9.8
# 05 v Stolkpark/Schev Bosjes                 1.3                         9.8
#
#                              % Westers|2023  twos  ones
# Buurten
# 01 Oud Scheveningen                    17.2     2     1
# 02 Vissershaven                        20.0     2     1
# 03 Scheveningen Badplaats              25.7     2     3
# 04 Visserijbuurt                       23.5     2     1
# 05 v Stolkpark/Schev Bosjes            35.9     2     1

# %% [markdown]
# * Permanently deleting variables is also within reach of one command:

# %%
# del db['ones']
# del db['twos']
db.head()
# Out:
#                              Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                                2983.0              151.0
# 02 Vissershaven                                    4416.0              195.0
# 03 Scheveningen Badplaats                          5670.0              262.0
# 04 Visserijbuurt                                   4048.0              178.0
# 05 v Stolkpark/Schev Bosjes                         843.0               29.0
#
#                              5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       272.0                115.0
# 02 Vissershaven                           466.0                219.0
# 03 Scheveningen Badplaats                 521.0                266.0
# 04 Visserijbuurt                          444.0                205.0
# 05 v Stolkpark/Schev Bosjes                75.0                 54.0
#
#                              20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       1035.0                855.0
# 02 Vissershaven                           1492.0               1185.0
# 03 Scheveningen Badplaats                 2113.0               1518.0
# 04 Visserijbuurt                          1343.0               1023.0
# 05 v Stolkpark/Schev Bosjes                204.0                254.0
#
#                              65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 01 Oud Scheveningen                        433.0                  122.0
# 02 Vissershaven                            701.0                  158.0
# 03 Scheveningen Badplaats                  788.0                  202.0
# 04 Visserijbuurt                           591.0                  264.0
# 05 v Stolkpark/Schev Bosjes                166.0                   61.0
#
#                              % Nederlands|2023  % Turks|2023  \
# Buurten
# 01 Oud Scheveningen                       71.8           0.6
# 02 Vissershaven                           66.3           1.2
# 03 Scheveningen Badplaats                 60.9           0.6
# 04 Visserijbuurt                          61.0           0.7
# 05 v Stolkpark/Schev Bosjes               49.9           0.8
#
#                              % Marokkaans|2023  % Surinaams|2023  \
# Buurten
# 01 Oud Scheveningen                        1.0               1.4
# 02 Vissershaven                            1.4               2.4
# 03 Scheveningen Badplaats                  0.4               1.8
# 04 Visserijbuurt                           1.6               1.9
# 05 v Stolkpark/Schev Bosjes                1.2               0.9
#
#                              % Antilliaans|2023  % Overig niet-westers|2023  \
# Buurten
# 01 Oud Scheveningen                         1.1                         6.9
# 02 Vissershaven                             1.0                         7.7
# 03 Scheveningen Badplaats                   1.1                         9.5
# 04 Visserijbuurt                            1.4                         9.8
# 05 v Stolkpark/Schev Bosjes                 1.3                         9.8
#
#                              % Westers|2023
# Buurten
# 01 Oud Scheveningen                    17.2
# 02 Vissershaven                        20.0
# 03 Scheveningen Badplaats              25.7
# 04 Visserijbuurt                       23.5
# 05 v Stolkpark/Schev Bosjes            35.9

# %% [markdown]
# * Index-based querying.
#
# We have already seen how to subset parts of a `DataFrame` if we know exactly which bits we want. For example, if we want to extract the total population and the share of Turkish people living in the first four neighbourhoods in the table, we use `loc` with lists:

# %%
db['# of Turks'] = (db['Aantal inwoners per 1-1|2023']*db['% Turks|2023'])
total_share_Turkish_first4 = db.loc[['01 Oud Scheveningen', '02 Vissershaven', '03 Scheveningen Badplaats', '04 Visserijbuurt'], \
                      ['Aantal inwoners per 1-1|2023', '% Turks|2023', '# of Turks']]

total_share_Turkish_first4
# Out:
#                            Aantal inwoners per 1-1|2023  % Turks|2023  \
# Buurten
# 01 Oud Scheveningen                              2983.0           0.6
# 02 Vissershaven                                  4416.0           1.2
# 03 Scheveningen Badplaats                        5670.0           0.6
# 04 Visserijbuurt                                 4048.0           0.7
#
#                            # of Turks
# Buurten
# 01 Oud Scheveningen            1789.8
# 02 Vissershaven                5299.2
# 03 Scheveningen Badplaats      3402.0
# 04 Visserijbuurt               2833.6

# %% [markdown]
# * Querying based on conditions.
#
# However, sometimes, we do not know exactly which observations we want, but we do know what conditions they need to satisfy (e.g. areas with more than 2,000 inhabitants). For these cases, `DataFrames` support selection based on conditions. Let us see a few examples. Suppose we want to select...
#
# *... areas with more than 2,500 people in Total*:

# %%
m2500 = db.loc[db['Aantal inwoners per 1-1|2023'] > 2500, :]
m2500
# Out:
#                            Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                              2983.0              151.0
# 02 Vissershaven                                  4416.0              195.0
# 03 Scheveningen Badplaats                        5670.0              262.0
# 04 Visserijbuurt                                 4048.0              178.0
# 07 Statenkwartier                               10618.0              410.0
# ...                                                 ...                ...
# 115 De Bras                                      5706.0              222.0
# 118 De Lanen                                     5368.0              272.0
# 119 De Velden                                    4162.0              145.0
# 120 De Vissen                                    8346.0              350.0
# 121 Rietbuurt                                    2758.0              145.0
#
#                            5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                     272.0                115.0
# 02 Vissershaven                         466.0                219.0
# 03 Scheveningen Badplaats               521.0                266.0
# 04 Visserijbuurt                        444.0                205.0
# 07 Statenkwartier                      1284.0                718.0
# ...                                       ...                  ...
# 115 De Bras                             967.0                680.0
# 118 De Lanen                            973.0                500.0
# 119 De Velden                           528.0                344.0
# 120 De Vissen                           998.0                704.0
# 121 Rietbuurt                           660.0                184.0
#
#                            20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                     1035.0                855.0
# 02 Vissershaven                         1492.0               1185.0
# 03 Scheveningen Badplaats               2113.0               1518.0
# 04 Visserijbuurt                        1343.0               1023.0
# 07 Statenkwartier                       3147.0               3139.0
# ...                                        ...                  ...
# 115 De Bras                             1332.0               2158.0
# 118 De Lanen                            1655.0               1657.0
# 119 De Velden                           1148.0               1427.0
# 120 De Vissen                           2077.0               2929.0
# 121 Rietbuurt                            873.0                742.0
#
#                            65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 01 Oud Scheveningen                      433.0                  122.0
# 02 Vissershaven                          701.0                  158.0
# 03 Scheveningen Badplaats                788.0                  202.0
# 04 Visserijbuurt                         591.0                  264.0
# 07 Statenkwartier                       1457.0                  463.0
# ...                                        ...                    ...
# 115 De Bras                              308.0                   39.0
# 118 De Lanen                             276.0                   35.0
# 119 De Velden                            491.0                   79.0
# 120 De Vissen                            998.0                  290.0
# 121 Rietbuurt                            137.0                   17.0
#
#                            % Nederlands|2023  % Turks|2023  % Marokkaans|2023  \
# Buurten
# 01 Oud Scheveningen                     71.8           0.6                1.0
# 02 Vissershaven                         66.3           1.2                1.4
# 03 Scheveningen Badplaats               60.9           0.6                0.4
# 04 Visserijbuurt                        61.0           0.7                1.6
# 07 Statenkwartier                       49.7           0.8                0.4
# ...                                      ...           ...                ...
# 115 De Bras                             67.0           3.0                3.3
# 118 De Lanen                            49.6           4.2                4.2
# 119 De Velden                           55.0           4.0                4.6
# 120 De Vissen                           58.3           2.6                4.0
# 121 Rietbuurt                           47.7           4.6                7.7
#
#                            % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 01 Oud Scheveningen                     1.4                 1.1
# 02 Vissershaven                         2.4                 1.0
# 03 Scheveningen Badplaats               1.8                 1.1
# 04 Visserijbuurt                        1.9                 1.4
# 07 Statenkwartier                       1.6                 1.2
# ...                                     ...                 ...
# 115 De Bras                             6.0                 1.2
# 118 De Lanen                           11.6                 2.9
# 119 De Velden                          10.3                 1.1
# 120 De Vissen                          11.5                 1.7
# 121 Rietbuurt                          10.8                 1.9
#
#                            % Overig niet-westers|2023  % Westers|2023  \
# Buurten
# 01 Oud Scheveningen                               6.9            17.2
# 02 Vissershaven                                   7.7            20.0
# 03 Scheveningen Badplaats                         9.5            25.7
# 04 Visserijbuurt                                  9.8            23.5
# 07 Statenkwartier                                 9.9            36.5
# ...                                               ...             ...
# 115 De Bras                                       7.0            12.4
# 118 De Lanen                                     16.0            11.5
# 119 De Velden                                    14.6            10.4
# 120 De Vissen                                    10.7            11.2
# 121 Rietbuurt                                    15.4            11.8
#
#                            # of Turks
# Buurten
# 01 Oud Scheveningen            1789.8
# 02 Vissershaven                5299.2
# 03 Scheveningen Badplaats      3402.0
# 04 Visserijbuurt               2833.6
# 07 Statenkwartier              8494.4
# ...                               ...
# 115 De Bras                   17118.0
# 118 De Lanen                  22545.6
# 119 De Velden                 16648.0
# 120 De Vissen                 21699.6
# 121 Rietbuurt                 12686.8
#
# [82 rows x 16 columns]

# %% [markdown]
# *... areas where there are no more than 10 people aged above 80.*:

# %%
# nm10_above_eighty = db.loc[db['80 jaar en ouder|2023'] <= 10, :]
# nm10_above_eighty

nm10_above80 = db.loc[db['80 jaar en ouder|2023']<=10, :]
nm10_above80
# Out:
#                        Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                         907.0               25.0
# 106 Vlietzoom-West                            182.0               10.0
# 116 Vlietzoom-Oost                            102.0                NaN
#
#                        5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                35.0                 47.0
# 106 Vlietzoom-West                   23.0                  9.0
# 116 Vlietzoom-Oost                    6.0                  NaN
#
#                        20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                583.0                162.0
# 106 Vlietzoom-West                    40.0                 60.0
# 116 Vlietzoom-Oost                    24.0                 33.0
#
#                        65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                 46.0                    9.0
# 106 Vlietzoom-West                    35.0                    5.0
# 116 Vlietzoom-Oost                    29.0                    5.0
#
#                        % Nederlands|2023  % Turks|2023  % Marokkaans|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid               25.2           2.3                2.2
# 106 Vlietzoom-West                  83.5           NaN                NaN
# 116 Vlietzoom-Oost                  75.5           NaN                NaN
#
#                        % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid               6.4                10.0
# 106 Vlietzoom-West                  NaN                 NaN
# 116 Vlietzoom-Oost                  NaN                 NaN
#
#                        % Overig niet-westers|2023  % Westers|2023  # of Turks
# Buurten
# 62 Rivierenbuurt-Zuid                        19.5            34.3      2086.1
# 106 Vlietzoom-West                            3.3             8.2         NaN
# 116 Vlietzoom-Oost                            NaN            20.6         NaN

# %% [markdown]
# *... areas with exactly nine person people aged above 80*:

# %%
nine_people_above_eighty = db.loc[db['80 jaar en ouder|2023'] == 9, :]
nine_people_above_eighty
# Out:
#                        Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                         907.0               25.0
#
#                        5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                35.0                 47.0
#
#                        20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                583.0                162.0
#
#                        65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                 46.0                    9.0
#
#                        % Nederlands|2023  % Turks|2023  % Marokkaans|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid               25.2           2.3                2.2
#
#                        % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid               6.4                10.0
#
#                        % Overig niet-westers|2023  % Westers|2023  # of Turks
# Buurten
# 62 Rivierenbuurt-Zuid                        19.5            34.3      2086.1

# %%
nine_above_eighty = db.loc[db['80 jaar en ouder|2023'] == 9, :]
nine_above_eighty
# Out:
#                        Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                         907.0               25.0
#
#                        5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                35.0                 47.0
#
#                        20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                583.0                162.0
#
#                        65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                 46.0                    9.0
#
#                        % Nederlands|2023  % Turks|2023  % Marokkaans|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid               25.2           2.3                2.2
#
#                        % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid               6.4                10.0
#
#                        % Overig niet-westers|2023  % Westers|2023  \
# Buurten
# 62 Rivierenbuurt-Zuid                        19.5            34.3
#
#                        % Non-Dutch | 2023
# Buurten
# 62 Rivierenbuurt-Zuid                74.7

# %% [markdown]
# **Pro-tip**: these queries can grow in sophistication with almost no limits. For example, here is a case where we want to find out the areas where European population is less than half the population:

# %%
nm_half_underaged = db.loc[((db['0 t/m 4 jaar|2023'] + db['5 t/m 14 jaar|2023'] + db['15 t/m 19 jaar|2023']) / db['Aantal inwoners per 1-1|2023']) < .5, :]
nm_half_underaged
# Out:
#                              Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                                2983.0              151.0
# 02 Vissershaven                                    4416.0              195.0
# 03 Scheveningen Badplaats                          5670.0              262.0
# 04 Visserijbuurt                                   4048.0              178.0
# 05 v Stolkpark/Schev Bosjes                         843.0               29.0
# ...                                                   ...                ...
# 115 De Bras                                        5706.0              222.0
# 118 De Lanen                                       5368.0              272.0
# 119 De Velden                                      4162.0              145.0
# 120 De Vissen                                      8346.0              350.0
# 121 Rietbuurt                                      2758.0              145.0
#
#                              5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       272.0                115.0
# 02 Vissershaven                           466.0                219.0
# 03 Scheveningen Badplaats                 521.0                266.0
# 04 Visserijbuurt                          444.0                205.0
# 05 v Stolkpark/Schev Bosjes                75.0                 54.0
# ...                                         ...                  ...
# 115 De Bras                               967.0                680.0
# 118 De Lanen                              973.0                500.0
# 119 De Velden                             528.0                344.0
# 120 De Vissen                             998.0                704.0
# 121 Rietbuurt                             660.0                184.0
#
#                              20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       1035.0                855.0
# 02 Vissershaven                           1492.0               1185.0
# 03 Scheveningen Badplaats                 2113.0               1518.0
# 04 Visserijbuurt                          1343.0               1023.0
# 05 v Stolkpark/Schev Bosjes                204.0                254.0
# ...                                          ...                  ...
# 115 De Bras                               1332.0               2158.0
# 118 De Lanen                              1655.0               1657.0
# 119 De Velden                             1148.0               1427.0
# 120 De Vissen                             2077.0               2929.0
# 121 Rietbuurt                              873.0                742.0
#
#                              65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 01 Oud Scheveningen                        433.0                  122.0
# 02 Vissershaven                            701.0                  158.0
# 03 Scheveningen Badplaats                  788.0                  202.0
# 04 Visserijbuurt                           591.0                  264.0
# 05 v Stolkpark/Schev Bosjes                166.0                   61.0
# ...                                          ...                    ...
# 115 De Bras                                308.0                   39.0
# 118 De Lanen                               276.0                   35.0
# 119 De Velden                              491.0                   79.0
# 120 De Vissen                              998.0                  290.0
# 121 Rietbuurt                              137.0                   17.0
#
#                              % Nederlands|2023  % Turks|2023  \
# Buurten
# 01 Oud Scheveningen                       71.8           0.6
# 02 Vissershaven                           66.3           1.2
# 03 Scheveningen Badplaats                 60.9           0.6
# 04 Visserijbuurt                          61.0           0.7
# 05 v Stolkpark/Schev Bosjes               49.9           0.8
# ...                                        ...           ...
# 115 De Bras                               67.0           3.0
# 118 De Lanen                              49.6           4.2
# 119 De Velden                             55.0           4.0
# 120 De Vissen                             58.3           2.6
# 121 Rietbuurt                             47.7           4.6
#
#                              % Marokkaans|2023  % Surinaams|2023  \
# Buurten
# 01 Oud Scheveningen                        1.0               1.4
# 02 Vissershaven                            1.4               2.4
# 03 Scheveningen Badplaats                  0.4               1.8
# 04 Visserijbuurt                           1.6               1.9
# 05 v Stolkpark/Schev Bosjes                1.2               0.9
# ...                                        ...               ...
# 115 De Bras                                3.3               6.0
# 118 De Lanen                               4.2              11.6
# 119 De Velden                              4.6              10.3
# 120 De Vissen                              4.0              11.5
# 121 Rietbuurt                              7.7              10.8
#
#                              % Antilliaans|2023  % Overig niet-westers|2023  \
# Buurten
# 01 Oud Scheveningen                         1.1                         6.9
# 02 Vissershaven                             1.0                         7.7
# 03 Scheveningen Badplaats                   1.1                         9.5
# 04 Visserijbuurt                            1.4                         9.8
# 05 v Stolkpark/Schev Bosjes                 1.3                         9.8
# ...                                         ...                         ...
# 115 De Bras                                 1.2                         7.0
# 118 De Lanen                                2.9                        16.0
# 119 De Velden                               1.1                        14.6
# 120 De Vissen                               1.7                        10.7
# 121 Rietbuurt                               1.9                        15.4
#
#                              % Westers|2023  % Non-Dutch | 2023
# Buurten
# 01 Oud Scheveningen                    17.2                28.2
# 02 Vissershaven                        20.0                33.7
# 03 Scheveningen Badplaats              25.7                39.1
# 04 Visserijbuurt                       23.5                38.9
# 05 v Stolkpark/Schev Bosjes            35.9                49.9
# ...                                     ...                 ...
# 115 De Bras                            12.4                32.9
# 118 De Lanen                           11.5                50.4
# 119 De Velden                          10.4                45.0
# 120 De Vissen                          11.2                41.7
# 121 Rietbuurt                          11.8                52.2
#
# [106 rows x 16 columns]

# %% [markdown]
# * Combining queries.
#
# Now all of these queries can be combined with each other, for further flexibility. For example, imagine we want areas with more than 25 toddlers but less than 1,500 in total:

# %%
# m25Toddlers_nm1500Total = db.loc[(db['0 t/m 4 jaar|2023'] > 25) & \
#                   (db['Aantal inwoners per 1-1|2023'] < 1500), :]
# m25Toddlers_nm1500Total

L100Teens_M250Total = db.loc[(db['15 t/m 19 jaar|2023'] <=100) & \
                             (db['Aantal inwoners per 1-1|2023'] >250), :]
L100Teens_M250Total
# Out:
#                              Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 05 v Stolkpark/Schev Bosjes                         843.0               29.0
# 06 Waldeck-Zuid                                    2052.0               74.0
# 12 Voorhout                                        2664.0               61.0
# 41 Zorgvliet                                        711.0               26.0
# 47 Willemspark                                     1779.0               58.0
# 48 Nassaubuurt                                     1644.0               75.0
# 49 Haagse Bos                                       469.0               10.0
# 60 Binckhorst                                      1254.0              101.0
# 62 Rivierenbuurt-Zuid                               907.0               25.0
# 68 Marlot                                           800.0               22.0
# 72 Rijslag                                         1743.0               69.0
# 73 Westbroekpark                                   1079.0               23.0
# 74 Duttendel                                       1183.0               52.0
# 75 Uilennest                                       2330.0              107.0
# 76 Duinzigt                                        2609.0               71.0
# 78 Arendsdorp                                      1973.0               83.0
# 81 Bosjes van Pex                                   380.0               11.0
# 90 Ockenburgh                                      1303.0               27.0
# 91 Kijkduin                                        1730.0               36.0
# 93 Componistenbuurt                                1842.0               52.0
# 94 Waldeck-Noord                                   3131.0               55.0
# 110 De Reef                                         688.0               68.0
# 111 De Venen                                       1798.0              138.0
#
#                              5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 05 v Stolkpark/Schev Bosjes                75.0                 54.0
# 06 Waldeck-Zuid                           195.0                 87.0
# 12 Voorhout                                99.0                 83.0
# 41 Zorgvliet                               58.0                 19.0
# 47 Willemspark                            113.0                 70.0
# 48 Nassaubuurt                            220.0                 99.0
# 49 Haagse Bos                               NaN                  8.0
# 60 Binckhorst                              45.0                 31.0
# 62 Rivierenbuurt-Zuid                      35.0                 47.0
# 68 Marlot                                 102.0                 68.0
# 72 Rijslag                                157.0                 88.0
# 73 Westbroekpark                           93.0                 54.0
# 74 Duttendel                              138.0                 83.0
# 75 Uilennest                              247.0                100.0
# 76 Duinzigt                               153.0                 99.0
# 78 Arendsdorp                             273.0                 97.0
# 81 Bosjes van Pex                          28.0                 25.0
# 90 Ockenburgh                             134.0                 76.0
# 91 Kijkduin                               146.0                 62.0
# 93 Componistenbuurt                       140.0                 75.0
# 94 Waldeck-Noord                          122.0                 50.0
# 110 De Reef                               102.0                 40.0
# 111 De Venen                              302.0                 94.0
#
#                              20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 05 v Stolkpark/Schev Bosjes                204.0                254.0
# 06 Waldeck-Zuid                            463.0                520.0
# 12 Voorhout                               1487.0                571.0
# 41 Zorgvliet                               138.0                199.0
# 47 Willemspark                             705.0                513.0
# 48 Nassaubuurt                             449.0                471.0
# 49 Haagse Bos                              153.0                 91.0
# 60 Binckhorst                              805.0                215.0
# 62 Rivierenbuurt-Zuid                      583.0                162.0
# 68 Marlot                                  147.0                252.0
# 72 Rijslag                                 534.0                433.0
# 73 Westbroekpark                           141.0                221.0
# 74 Duttendel                               208.0                307.0
# 75 Uilennest                               641.0                647.0
# 76 Duinzigt                                435.0                503.0
# 78 Arendsdorp                              523.0                491.0
# 81 Bosjes van Pex                           78.0                141.0
# 90 Ockenburgh                              274.0                459.0
# 91 Kijkduin                                311.0                469.0
# 93 Componistenbuurt                        376.0                529.0
# 94 Waldeck-Noord                           581.0                641.0
# 110 De Reef                                351.0                 95.0
# 111 De Venen                               743.0                400.0
#
#                              65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 05 v Stolkpark/Schev Bosjes                166.0                   61.0
# 06 Waldeck-Zuid                            492.0                  221.0
# 12 Voorhout                                286.0                   77.0
# 41 Zorgvliet                               207.0                   64.0
# 47 Willemspark                             248.0                   72.0
# 48 Nassaubuurt                             252.0                   78.0
# 49 Haagse Bos                              118.0                   86.0
# 60 Binckhorst                               55.0                    NaN
# 62 Rivierenbuurt-Zuid                       46.0                    9.0
# 68 Marlot                                  167.0                   42.0
# 72 Rijslag                                 253.0                  209.0
# 73 Westbroekpark                           339.0                  208.0
# 74 Duttendel                               241.0                  154.0
# 75 Uilennest                               378.0                  210.0
# 76 Duinzigt                                700.0                  648.0
# 78 Arendsdorp                              316.0                  190.0
# 81 Bosjes van Pex                           78.0                   19.0
# 90 Ockenburgh                              307.0                   26.0
# 91 Kijkduin                                508.0                  198.0
# 93 Componistenbuurt                        474.0                  196.0
# 94 Waldeck-Noord                           981.0                  701.0
# 110 De Reef                                 29.0                    NaN
# 111 De Venen                               109.0                   12.0
#
#                              % Nederlands|2023  % Turks|2023  \
# Buurten
# 05 v Stolkpark/Schev Bosjes               49.9           0.8
# 06 Waldeck-Zuid                           59.0           3.0
# 12 Voorhout                               41.4           2.0
# 41 Zorgvliet                              52.5           NaN
# 47 Willemspark                            43.8           1.7
# 48 Nassaubuurt                            56.2           0.4
# 49 Haagse Bos                             48.2           2.6
# 60 Binckhorst                             44.8           4.6
# 62 Rivierenbuurt-Zuid                     25.2           2.3
# 68 Marlot                                 59.3           NaN
# 72 Rijslag                                64.9           1.1
# 73 Westbroekpark                          64.6           0.5
# 74 Duttendel                              65.0           NaN
# 75 Uilennest                              53.4           0.8
# 76 Duinzigt                               61.5           0.6
# 78 Arendsdorp                             47.9           0.6
# 81 Bosjes van Pex                         68.7           NaN
# 90 Ockenburgh                             68.7           0.7
# 91 Kijkduin                               73.2           1.1
# 93 Componistenbuurt                       68.4           0.4
# 94 Waldeck-Noord                          68.8           1.1
# 110 De Reef                               24.1          14.4
# 111 De Venen                              41.3           7.3
#
#                              % Marokkaans|2023  % Surinaams|2023  \
# Buurten
# 05 v Stolkpark/Schev Bosjes                1.2               0.9
# 06 Waldeck-Zuid                            2.2               4.0
# 12 Voorhout                                1.3               2.0
# 41 Zorgvliet                               NaN               NaN
# 47 Willemspark                             0.7               1.1
# 48 Nassaubuurt                             NaN               1.0
# 49 Haagse Bos                              NaN               NaN
# 60 Binckhorst                              2.4               4.9
# 62 Rivierenbuurt-Zuid                      2.2               6.4
# 68 Marlot                                  NaN               NaN
# 72 Rijslag                                 0.7               2.2
# 73 Westbroekpark                           NaN               0.8
# 74 Duttendel                               NaN               NaN
# 75 Uilennest                               0.6               1.2
# 76 Duinzigt                                0.2               0.7
# 78 Arendsdorp                              0.3               0.8
# 81 Bosjes van Pex                          NaN               2.1
# 90 Ockenburgh                              NaN               2.6
# 91 Kijkduin                                0.5               1.0
# 93 Componistenbuurt                        NaN               1.7
# 94 Waldeck-Noord                           0.4               2.4
# 110 De Reef                                4.7              18.9
# 111 De Venen                               5.8              14.3
#
#                              % Antilliaans|2023  % Overig niet-westers|2023  \
# Buurten
# 05 v Stolkpark/Schev Bosjes                 1.3                         9.8
# 06 Waldeck-Zuid                             1.9                        13.6
# 12 Voorhout                                 1.5                        16.6
# 41 Zorgvliet                                NaN                        11.1
# 47 Willemspark                              0.8                        13.7
# 48 Nassaubuurt                              0.6                        10.2
# 49 Haagse Bos                               NaN                        15.6
# 60 Binckhorst                               6.1                        18.3
# 62 Rivierenbuurt-Zuid                      10.0                        19.5
# 68 Marlot                                   NaN                        12.3
# 72 Rijslag                                  1.4                         6.8
# 73 Westbroekpark                            0.7                         7.0
# 74 Duttendel                                1.3                         7.8
# 75 Uilennest                                0.7                        12.1
# 76 Duinzigt                                 0.7                         8.1
# 78 Arendsdorp                               0.5                        12.7
# 81 Bosjes van Pex                           NaN                         7.1
# 90 Ockenburgh                               1.1                         8.9
# 91 Kijkduin                                 0.4                         6.2
# 93 Componistenbuurt                         0.9                         6.2
# 94 Waldeck-Noord                            1.0                         8.7
# 110 De Reef                                 3.5                        23.1
# 111 De Venen                                2.7                        15.9
#
#                              % Westers|2023  # of Turks
# Buurten
# 05 v Stolkpark/Schev Bosjes            35.9       674.4
# 06 Waldeck-Zuid                        16.4      6156.0
# 12 Voorhout                            35.4      5328.0
# 41 Zorgvliet                           35.9         NaN
# 47 Willemspark                         38.1      3024.3
# 48 Nassaubuurt                         31.4       657.6
# 49 Haagse Bos                          32.6      1219.4
# 60 Binckhorst                          18.9      5768.4
# 62 Rivierenbuurt-Zuid                  34.3      2086.1
# 68 Marlot                              27.8         NaN
# 72 Rijslag                             22.8      1917.3
# 73 Westbroekpark                       26.0       539.5
# 74 Duttendel                           25.4         NaN
# 75 Uilennest                           31.2      1864.0
# 76 Duinzigt                            28.2      1565.4
# 78 Arendsdorp                          37.3      1183.8
# 81 Bosjes van Pex                      21.1         NaN
# 90 Ockenburgh                          17.7       912.1
# 91 Kijkduin                            17.6      1903.0
# 93 Componistenbuurt                    22.2       736.8
# 94 Waldeck-Noord                       17.6      3444.1
# 110 De Reef                            11.3      9907.2
# 111 De Venen                           12.8     13125.4

# %% [markdown]
# * Sorting.
#
# Among the many operations `DataFrame` objects support, one of the most useful ones is to sort a table based on a given column. For example, imagine we want to sort the table by Toddlers:

# %%
#db_Toddlers_sorted = db.sort_values('0 t/m 4 jaar|2023', ascending=False)
#db_Toddlers_sorted.head()

db_OldestBuurten = db.sort_values('80 jaar en ouder|2023', ascending=False)
db_OldestBuurten.head(10)
# Out:
#                         Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 84 Leyenburg                                 16749.0              889.0
# 94 Waldeck-Noord                              3131.0               55.0
# 76 Duinzigt                                   2609.0               71.0
# 92 Bohemen/Meer en Bos                        4531.0              140.0
# 95 Kom Loosduinen                             5042.0              181.0
# 86 Houtwijk                                  12746.0              579.0
# 98 Dreven en Gaarden                         11097.0              733.0
# 69 Burgen en Horsten                          6696.0              326.0
# 07 Statenkwartier                            10618.0              410.0
# 71 Belgisch Park                              8383.0              359.0
#
#                         5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 84 Leyenburg                        1472.0                744.0
# 94 Waldeck-Noord                     122.0                 50.0
# 76 Duinzigt                          153.0                 99.0
# 92 Bohemen/Meer en Bos               259.0                152.0
# 95 Kom Loosduinen                    405.0                194.0
# 86 Houtwijk                         1491.0                766.0
# 98 Dreven en Gaarden                1498.0                717.0
# 69 Burgen en Horsten                 604.0                242.0
# 07 Statenkwartier                   1284.0                718.0
# 71 Belgisch Park                     864.0                625.0
#
#                         20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 84 Leyenburg                         6768.0               4004.0
# 94 Waldeck-Noord                      581.0                641.0
# 76 Duinzigt                           435.0                503.0
# 92 Bohemen/Meer en Bos                977.0               1195.0
# 95 Kom Loosduinen                    1401.0               1252.0
# 86 Houtwijk                          3544.0               3455.0
# 98 Dreven en Gaarden                 3849.0               2577.0
# 69 Burgen en Horsten                 2364.0               1608.0
# 07 Statenkwartier                    3147.0               3139.0
# 71 Belgisch Park                     2448.0               2338.0
#
#                         65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 84 Leyenburg                         2122.0                  750.0
# 94 Waldeck-Noord                      981.0                  701.0
# 76 Duinzigt                           700.0                  648.0
# 92 Bohemen/Meer en Bos               1202.0                  606.0
# 95 Kom Loosduinen                    1040.0                  569.0
# 86 Houtwijk                          2343.0                  568.0
# 98 Dreven en Gaarden                 1176.0                  547.0
# 69 Burgen en Horsten                 1062.0                  490.0
# 07 Statenkwartier                    1457.0                  463.0
# 71 Belgisch Park                     1344.0                  405.0
#
#                         % Nederlands|2023  % Turks|2023  % Marokkaans|2023  \
# Buurten
# 84 Leyenburg                         52.7           4.5                2.3
# 94 Waldeck-Noord                     68.8           1.1                0.4
# 76 Duinzigt                          61.5           0.6                0.2
# 92 Bohemen/Meer en Bos               69.9           0.8                0.2
# 95 Kom Loosduinen                    68.1           1.7                2.4
# 86 Houtwijk                          60.1           4.8                4.4
# 98 Dreven en Gaarden                 22.0          17.8               13.8
# 69 Burgen en Horsten                 44.0           2.2                3.9
# 07 Statenkwartier                    49.7           0.8                0.4
# 71 Belgisch Park                     61.8           0.8                0.6
#
#                         % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 84 Leyenburg                         6.9                 2.4
# 94 Waldeck-Noord                     2.4                 1.0
# 76 Duinzigt                          0.7                 0.7
# 92 Bohemen/Meer en Bos               1.8                 0.6
# 95 Kom Loosduinen                    4.3                 1.7
# 86 Houtwijk                          6.3                 1.6
# 98 Dreven en Gaarden                11.7                 4.5
# 69 Burgen en Horsten                 5.2                 2.9
# 07 Statenkwartier                    1.6                 1.2
# 71 Belgisch Park                     2.0                 1.1
#
#                         % Overig niet-westers|2023  % Westers|2023  # of Turks
# Buurten
# 84 Leyenburg                                   9.0            22.3     75370.5
# 94 Waldeck-Noord                               8.7            17.6      3444.1
# 76 Duinzigt                                    8.1            28.2      1565.4
# 92 Bohemen/Meer en Bos                         6.2            20.4      3624.8
# 95 Kom Loosduinen                              6.6            15.2      8571.4
# 86 Houtwijk                                    8.9            13.9     61180.8
# 98 Dreven en Gaarden                          15.2            15.1    197526.6
# 69 Burgen en Horsten                          20.8            20.9     14731.2
# 07 Statenkwartier                              9.9            36.5      8494.4
# 71 Belgisch Park                               9.5            24.2      6706.4

# %% [markdown]
# If you inspect the help of `db.sort_values`, you will find that you can pass more than one column to sort the table by. This allows you to do so-called hiearchical sorting: sort first based on one column, if equal then based on another column, etc.
#
# ## Visual Exploration <a class="anchor" id="section2"></a>
#
# The next step to continue exploring a dataset is to get a feel for what it looks like, visually. We have already learnt how to unconver and inspect specific parts of the data, to check for particular cases we might be intersted in. Now we will see how to plot the data to get a sense of the overall distribution of values. For that, we will be using the Python library [`seaborn`](http://stanford.edu/~mwaskom/software/seaborn/index.html).

# %% [markdown]
# ### Histograms <a class="anchor" id="section_2_1"></a>
#
# One of the most common graphical devices to display the distribution of values in a variable is a histogram. Values are assigned into groups of equal intervals, and the groups are plotted as bars rising as high as the number of values into the group.
#
# A histogram is easily created with the following command. In this case, let us have a look at the shape of the overall population:

# %%
#_ = sns.displot(db['Aantal inwoners per 1-1|2023'], kde=False)

test = sns.displot(db['0 t/m 4 jaar|2023'], kde=True, rug=True)

# %% [markdown]
# Note we are using `sns` instead of `pd`, as the function belongs to `seaborn` instead of `pandas`.
#
# We can quickly see most of the areas contain somewhere between 1,200 and 1,700 people, approx. However, there are a few areas that have many more, even up to 3,500 people.
#
# An additional feature to visualize the density of values is called `rug`, and adds a little tick for each value on the horizontal axis:

# %%
_ = sns.displot(db['Aantal inwoners per 1-1|2023'], kde=False, rug=True)

# %% [markdown]
# ### Kernel Density Plots <a class="anchor" id="section_2_2"></a>
#
# Histograms are useful, but they are artificial in the sense that a continuous variable is made discrete by turning the values into discrete groups. An alternative is kernel density estimation (KDE), which produces an empirical density function:

# %%
# _ = sns.kdeplot(db['Aantal inwoners per 1-1|2023'], fill=True)

old = sns.kdeplot(db['80 jaar en ouder|2023'], fill=True)

# %% [markdown]
# ### Line and Bar plots <a class="anchor" id="section_2_3"></a>
#
# Another very common way of visually displaying a variable is with a line or a bar chart. For example, if we want to generate a line plot of the (sorted) total population by area:

# %%
# _ = db['Aantal inwoners per 1-1|2023'].sort_values(ascending=False).plot()

test = db['80 jaar en ouder|2023'].sort_values().plot()

# %% [markdown]
# For a bar plot all we need to do is to change an argument of the call:

# %%
_ = db['Aantal inwoners per 1-1|2023'].sort_values(ascending=False).plot(kind='bar')

# %% [markdown]
# Note that the large number of areas makes the horizontal axis unreadable. We can try to turn the plot around by displaying the bars horizontally (see how it's just changing `bar` for `barh`). To make it readable, let us expand the plot's height:

# %%
_ = db['Aantal inwoners per 1-1|2023'].sort_values().plot(kind='barh', figsize=(10, 36), fontsize=(12))

# %% [markdown]
# ## (Un)tidy data <a class="anchor" id="section3"></a>
#
# > *Happy families are all alike; every
# unhappy family is unhappy in its own
# way.*
#
# > Leo Tolstoy.
#
# Once you can read your data in, explore specific cases, and have a first visual approach to the entire set, the next step can be preparing it for more sophisticated analysis. Maybe you are thinking of modeling it through regression, or on creating subgroups in the dataset with particular characteristics, or maybe you simply need to present summary measures that relate to a slightly different arrangement of the data than you have been presented with.
#
# For all these cases, you first need what statistician, and general R wizard, Hadley Wickham calls *"tidy data"*. The general idea to "tidy" your data is to convert them from whatever structure they were handed in to you into one that allows convenient and standardized manipulation, and that supports directly inputting the data into what he calls "*tidy*" analysis tools. But, at a more practical level, what is exactly *"tidy data"*? In Wickham's own words:
#
# > *Tidy data is a standard way of mapping the meaning of a dataset to its structure. A dataset is
# messy or tidy depending on how rows, columns and tables are matched up with observations,
# variables and types.*
#
# He then goes on to list the three fundamental characteristics of *"tidy data"*:
#
# 1. Each variable forms a column.
# 1. Each observation forms a row.
# 1. Each type of observational unit forms a table.
#
# If you are further interested in the concept of *"tidy data"*, I recommend you check out the [original paper](https://www.jstatsoft.org/v59/i10/) (open access) and the [public repository](https://github.com/hadley/tidy-data) associated with it.
#
# Let us bring in the concept of "*tidy data*" to our own The Hague dataset. First, remember its structure:

# %%
db.head()
# Out:
#                              Aantal inwoners per 1-1|2023  0 t/m 4 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                                2983.0              151.0
# 02 Vissershaven                                    4416.0              195.0
# 03 Scheveningen Badplaats                          5670.0              262.0
# 04 Visserijbuurt                                   4048.0              178.0
# 05 v Stolkpark/Schev Bosjes                         843.0               29.0
#
#                              5 t/m 14 jaar|2023  15 t/m 19 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       272.0                115.0
# 02 Vissershaven                           466.0                219.0
# 03 Scheveningen Badplaats                 521.0                266.0
# 04 Visserijbuurt                          444.0                205.0
# 05 v Stolkpark/Schev Bosjes                75.0                 54.0
#
#                              20 t/m 44 jaar|2023  45 t/m 64 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                       1035.0                855.0
# 02 Vissershaven                           1492.0               1185.0
# 03 Scheveningen Badplaats                 2113.0               1518.0
# 04 Visserijbuurt                          1343.0               1023.0
# 05 v Stolkpark/Schev Bosjes                204.0                254.0
#
#                              65 t/m 79 jaar|2023  80 jaar en ouder|2023  \
# Buurten
# 01 Oud Scheveningen                        433.0                  122.0
# 02 Vissershaven                            701.0                  158.0
# 03 Scheveningen Badplaats                  788.0                  202.0
# 04 Visserijbuurt                           591.0                  264.0
# 05 v Stolkpark/Schev Bosjes                166.0                   61.0
#
#                              % Nederlands|2023  % Turks|2023  \
# Buurten
# 01 Oud Scheveningen                       71.8           0.6
# 02 Vissershaven                           66.3           1.2
# 03 Scheveningen Badplaats                 60.9           0.6
# 04 Visserijbuurt                          61.0           0.7
# 05 v Stolkpark/Schev Bosjes               49.9           0.8
#
#                              % Marokkaans|2023  % Surinaams|2023  \
# Buurten
# 01 Oud Scheveningen                        1.0               1.4
# 02 Vissershaven                            1.4               2.4
# 03 Scheveningen Badplaats                  0.4               1.8
# 04 Visserijbuurt                           1.6               1.9
# 05 v Stolkpark/Schev Bosjes                1.2               0.9
#
#                              % Antilliaans|2023  % Overig niet-westers|2023  \
# Buurten
# 01 Oud Scheveningen                         1.1                         6.9
# 02 Vissershaven                             1.0                         7.7
# 03 Scheveningen Badplaats                   1.1                         9.5
# 04 Visserijbuurt                            1.4                         9.8
# 05 v Stolkpark/Schev Bosjes                 1.3                         9.8
#
#                              % Westers|2023  % Non-Dutch | 2023
# Buurten
# 01 Oud Scheveningen                    17.2                28.2
# 02 Vissershaven                        20.0                33.7
# 03 Scheveningen Badplaats              25.7                39.1
# 04 Visserijbuurt                       23.5                38.9
# 05 v Stolkpark/Schev Bosjes            35.9                49.9

# %% [markdown]
# Thinking through *tidy* lenses, this is not a tidy dataset. It is not so for each of the three conditions:
#
# * Starting by the last one (*each type of observational unit forms a table*), this dataset actually contains not one but two observational units: the different areas of The Hague, captured by `Buurten`; *and* subgroups of an area. To *tidy* up this aspect, we can create two different tables:

# %%
# Assign column `Aantal inwoners per 1-1|2023` into its own as a single-column table
db_totals = db[['Aantal inwoners per 1-1|2023']]
db_totals.head()
# Out:
#                              Aantal inwoners per 1-1|2023
# Buurten
# 01 Oud Scheveningen                                2983.0
# 02 Vissershaven                                    4416.0
# 03 Scheveningen Badplaats                          5670.0
# 04 Visserijbuurt                                   4048.0
# 05 v Stolkpark/Schev Bosjes                         843.0

# %%
# Create a table `db_subgroups` that contains every column in `db` without `Aantal inwoners per 1-1|2023`
db_subgroups = db.drop('Aantal inwoners per 1-1|2023', axis=1)
db_subgroups.head()
# Out:
#                              0 t/m 4 jaar|2023  5 t/m 14 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                      151.0               272.0
# 02 Vissershaven                          195.0               466.0
# 03 Scheveningen Badplaats                262.0               521.0
# 04 Visserijbuurt                         178.0               444.0
# 05 v Stolkpark/Schev Bosjes               29.0                75.0
#
#                              15 t/m 19 jaar|2023  20 t/m 44 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                        115.0               1035.0
# 02 Vissershaven                            219.0               1492.0
# 03 Scheveningen Badplaats                  266.0               2113.0
# 04 Visserijbuurt                           205.0               1343.0
# 05 v Stolkpark/Schev Bosjes                 54.0                204.0
#
#                              45 t/m 64 jaar|2023  65 t/m 79 jaar|2023  \
# Buurten
# 01 Oud Scheveningen                        855.0                433.0
# 02 Vissershaven                           1185.0                701.0
# 03 Scheveningen Badplaats                 1518.0                788.0
# 04 Visserijbuurt                          1023.0                591.0
# 05 v Stolkpark/Schev Bosjes                254.0                166.0
#
#                              80 jaar en ouder|2023  % Nederlands|2023  \
# Buurten
# 01 Oud Scheveningen                          122.0               71.8
# 02 Vissershaven                              158.0               66.3
# 03 Scheveningen Badplaats                    202.0               60.9
# 04 Visserijbuurt                             264.0               61.0
# 05 v Stolkpark/Schev Bosjes                   61.0               49.9
#
#                              % Turks|2023  % Marokkaans|2023  \
# Buurten
# 01 Oud Scheveningen                   0.6                1.0
# 02 Vissershaven                       1.2                1.4
# 03 Scheveningen Badplaats             0.6                0.4
# 04 Visserijbuurt                      0.7                1.6
# 05 v Stolkpark/Schev Bosjes           0.8                1.2
#
#                              % Surinaams|2023  % Antilliaans|2023  \
# Buurten
# 01 Oud Scheveningen                       1.4                 1.1
# 02 Vissershaven                           2.4                 1.0
# 03 Scheveningen Badplaats                 1.8                 1.1
# 04 Visserijbuurt                          1.9                 1.4
# 05 v Stolkpark/Schev Bosjes               0.9                 1.3
#
#                              % Overig niet-westers|2023  % Westers|2023  \
# Buurten
# 01 Oud Scheveningen                                 6.9            17.2
# 02 Vissershaven                                     7.7            20.0
# 03 Scheveningen Badplaats                           9.5            25.7
# 04 Visserijbuurt                                    9.8            23.5
# 05 v Stolkpark/Schev Bosjes                         9.8            35.9
#
#                              # of Turks
# Buurten
# 01 Oud Scheveningen              1789.8
# 02 Vissershaven                  5299.2
# 03 Scheveningen Badplaats        3402.0
# 04 Visserijbuurt                 2833.6
# 05 v Stolkpark/Schev Bosjes       674.4

# %% [markdown]
# Note we use `drop` to exclude `Aantal inwoners per 1-1|2023`, but we could also use a list with the names of all the columns to keep. Additionally, notice how, in this case, the use of `drop` (which leaves `db` untouched) is preferred to that of `del` (which permanently removes the column from `db`).
#
# At this point, the table `db_totals` is tidy: every row is an observation, every column is a variable, and there is only one observational unit in the table.
#
# The other table (`db_subgroups`), however, is not entirely tidied up yet: there is only one observational unit in the table, true; but every row is not an observation, and there are variable values as the names of columns (in other words, every column is not a variable). To obtain a fully tidy version of the table, we need to re-arrange it in a way that every row is a population subgroup in an area, and there are three variables: `Buurten`, age subgroup, and count (or frequency).
#
# Because this is actually a fairly common pattern, there is a direct way to solve it in `pandas`:

# %%
tidy_subgroups = db_subgroups.stack()
tidy_subgroups.head(10)
# Out:
# Buurten
# 01 Oud Scheveningen  0 t/m 4 jaar|2023         151.0
#                      5 t/m 14 jaar|2023        272.0
#                      15 t/m 19 jaar|2023       115.0
#                      20 t/m 44 jaar|2023      1035.0
#                      45 t/m 64 jaar|2023       855.0
#                      65 t/m 79 jaar|2023       433.0
#                      80 jaar en ouder|2023     122.0
#                      % Nederlands|2023          71.8
#                      % Turks|2023                0.6
#                      % Marokkaans|2023           1.0
# dtype: float64

# %% [markdown]
# The method `stack`, well, "stacks" the different columns into rows. This fixes our "tidiness" problems but the type of object that is returning is not a `DataFrame`:

# %%
type(tidy_subgroups)
# Out:
# pandas.core.series.Series

# %% [markdown]
# It is a `Series`, which really is like a `DataFrame`, but with only one column. The additional information (`Buurten` and age group) are stored in what is called an multi-index. We will skip these for now, so we would really just want to get a `DataFrame` as we know it out of the `Series`. This is also one line of code away:

# %%
# Unfold the multi-index into different, new columns
tidy_subgroupsDF = tidy_subgroups.reset_index()
tidy_subgroupsDF.head(20)
# Out:
#                 Buurten                     level_1       0
# 0   01 Oud Scheveningen           0 t/m 4 jaar|2023   151.0
# 1   01 Oud Scheveningen          5 t/m 14 jaar|2023   272.0
# 2   01 Oud Scheveningen         15 t/m 19 jaar|2023   115.0
# 3   01 Oud Scheveningen         20 t/m 44 jaar|2023  1035.0
# 4   01 Oud Scheveningen         45 t/m 64 jaar|2023   855.0
# 5   01 Oud Scheveningen         65 t/m 79 jaar|2023   433.0
# 6   01 Oud Scheveningen       80 jaar en ouder|2023   122.0
# 7   01 Oud Scheveningen           % Nederlands|2023    71.8
# 8   01 Oud Scheveningen                % Turks|2023     0.6
# 9   01 Oud Scheveningen           % Marokkaans|2023     1.0
# 10  01 Oud Scheveningen            % Surinaams|2023     1.4
# 11  01 Oud Scheveningen          % Antilliaans|2023     1.1
# 12  01 Oud Scheveningen  % Overig niet-westers|2023     6.9
# 13  01 Oud Scheveningen              % Westers|2023    17.2
# 14  01 Oud Scheveningen                  # of Turks  1789.8
# 15      02 Vissershaven           0 t/m 4 jaar|2023   195.0
# 16      02 Vissershaven          5 t/m 14 jaar|2023   466.0
# 17      02 Vissershaven         15 t/m 19 jaar|2023   219.0
# 18      02 Vissershaven         20 t/m 44 jaar|2023  1492.0
# 19      02 Vissershaven         45 t/m 64 jaar|2023  1185.0

# %% [markdown]
# To which we can apply to renaming to make it look better:

# %%
tidy_subgroupsDF = tidy_subgroupsDF.rename(columns={'level_1': 'Subgroup', 0: 'Freq'})
tidy_subgroupsDF.head(20)
# Out:
#                 Buurten                    Subgroup    Freq
# 0   01 Oud Scheveningen           0 t/m 4 jaar|2023   151.0
# 1   01 Oud Scheveningen          5 t/m 14 jaar|2023   272.0
# 2   01 Oud Scheveningen         15 t/m 19 jaar|2023   115.0
# 3   01 Oud Scheveningen         20 t/m 44 jaar|2023  1035.0
# 4   01 Oud Scheveningen         45 t/m 64 jaar|2023   855.0
# 5   01 Oud Scheveningen         65 t/m 79 jaar|2023   433.0
# 6   01 Oud Scheveningen       80 jaar en ouder|2023   122.0
# 7   01 Oud Scheveningen           % Nederlands|2023    71.8
# 8   01 Oud Scheveningen                % Turks|2023     0.6
# 9   01 Oud Scheveningen           % Marokkaans|2023     1.0
# 10  01 Oud Scheveningen            % Surinaams|2023     1.4
# 11  01 Oud Scheveningen          % Antilliaans|2023     1.1
# 12  01 Oud Scheveningen  % Overig niet-westers|2023     6.9
# 13  01 Oud Scheveningen              % Westers|2023    17.2
# 14  01 Oud Scheveningen                  # of Turks  1789.8
# 15      02 Vissershaven           0 t/m 4 jaar|2023   195.0
# 16      02 Vissershaven          5 t/m 14 jaar|2023   466.0
# 17      02 Vissershaven         15 t/m 19 jaar|2023   219.0
# 18      02 Vissershaven         20 t/m 44 jaar|2023  1492.0
# 19      02 Vissershaven         45 t/m 64 jaar|2023  1185.0

# %% [markdown]
# Now our table is fully tidied up!
#
# ### Grouping, transforming, aggregating <a class="anchor" id="section_3_1"></a>
#
# One of the advantage of tidy datasets is they allow to perform advanced transformations in a more direct way. One of the most common ones is what is called "group-by" operations. Originated in the world of databases, these operations allow you to group observations in a table by one of its labels, index, or category, and apply operations on the data group by group.
#
# For example, given our tidy table with population subgroups, we might want to compute the total sum of population by each group. This task can be split into two different ones:
#
# * Group the table in each of the different subgroups.
# * Compute the sum of `Freq` for each of them.
#
# To do this in `pandas`, meet one of its workhorses, and also one of the reasons why the library has become so popular: the `groupby` operator.

# %%
pop_grouped = tidy_subgroupsDF.groupby('Subgroup')
pop_grouped

# %% [markdown]
# The object `pop_grouped` still hasn't computed anything, it is only a convenient way of specifying the grouping. But this allows us then to perform a multitude of operations on it. For our example, the sum is calculated as follows:

# %%
pop_grouped.sum()
# Out:
#                                                                       Buurten  \
# Subgroup
# # of Turks                  01 Oud Scheveningen02 Vissershaven03 Schevenin...
# % Antilliaans|2023          01 Oud Scheveningen02 Vissershaven03 Schevenin...
# % Marokkaans|2023           01 Oud Scheveningen02 Vissershaven03 Schevenin...
# % Nederlands|2023           01 Oud Scheveningen02 Vissershaven03 Schevenin...
# % Overig niet-westers|2023  01 Oud Scheveningen02 Vissershaven03 Schevenin...
# % Surinaams|2023            01 Oud Scheveningen02 Vissershaven03 Schevenin...
# % Turks|2023                01 Oud Scheveningen02 Vissershaven03 Schevenin...
# % Westers|2023              01 Oud Scheveningen02 Vissershaven03 Schevenin...
# 0 t/m 4 jaar|2023           01 Oud Scheveningen02 Vissershaven03 Schevenin...
# 15 t/m 19 jaar|2023         01 Oud Scheveningen02 Vissershaven03 Schevenin...
# 20 t/m 44 jaar|2023         01 Oud Scheveningen02 Vissershaven03 Schevenin...
# 45 t/m 64 jaar|2023         01 Oud Scheveningen02 Vissershaven03 Schevenin...
# 5 t/m 14 jaar|2023          01 Oud Scheveningen02 Vissershaven03 Schevenin...
# 65 t/m 79 jaar|2023         01 Oud Scheveningen02 Vissershaven03 Schevenin...
# 80 jaar en ouder|2023       01 Oud Scheveningen02 Vissershaven03 Schevenin...
#
#                                  Freq
# Subgroup
# # of Turks                  4319925.6
# % Antilliaans|2023              253.0
# % Marokkaans|2023               500.8
# % Nederlands|2023              5167.4
# % Overig niet-westers|2023     1380.0
# % Surinaams|2023                744.0
# % Turks|2023                    665.8
# % Westers|2023                 2365.1
# 0 t/m 4 jaar|2023             28777.0
# 15 t/m 19 jaar|2023           32414.0
# 20 t/m 44 jaar|2023          210593.0
# 45 t/m 64 jaar|2023          145286.0
# 5 t/m 14 jaar|2023            61484.0
# 65 t/m 79 jaar|2023           64863.0
# 80 jaar en ouder|2023         19681.0

# %% [markdown]
# Similarly, you can also obtain a summary of each group:

# %%
pop_grouped.describe()
# Out:
#                              Freq                                           \
#                             count         mean          std   min      25%
# Subgroup
# % Antilliaans|2023          102.0     2.480392     2.011110   0.3    1.100
# % Marokkaans|2023            95.0     5.271579     5.309900   0.1    1.100
# % Nederlands|2023           111.0    46.553153    20.036666   5.8   27.900
# % Non-Dutch | 2023           94.0    56.654255    19.206835  21.0   40.100
# % Overig niet-westers|2023  109.0    12.660550     5.379695   3.3    8.800
# % Surinaams|2023            104.0     7.153846     5.091472   0.5    2.200
# % Turks|2023                103.0     6.464078     7.530967   0.3    1.050
# % Westers|2023              110.0    21.500909     8.391034   7.3   13.975
# 0 t/m 4 jaar|2023           107.0   268.943925   189.016363  10.0  118.500
# 15 t/m 19 jaar|2023         107.0   302.934579   213.279083   8.0  110.500
# 20 t/m 44 jaar|2023         110.0  1914.481818  1474.818973   5.0  714.500
# 45 t/m 64 jaar|2023         111.0  1308.882883   861.831124  13.0  644.000
# 5 t/m 14 jaar|2023          107.0   574.616822   393.491067   6.0  257.000
# 65 t/m 79 jaar|2023         110.0   589.663636   406.969022   5.0  316.500
# 80 jaar en ouder|2023       107.0   183.934579   154.038483   5.0   80.000
#
#
#                                 50%       75%     max
# Subgroup
# % Antilliaans|2023             1.85     3.400    11.7
# % Marokkaans|2023              3.90     7.750    24.7
# % Nederlands|2023             49.60    61.250   100.0
# % Non-Dutch | 2023            54.10    75.600    94.2
# % Overig niet-westers|2023    11.10    16.600    28.0
# % Surinaams|2023               6.70    11.525    21.1
# % Turks|2023                   3.00    10.000    28.4
# % Westers|2023                20.75    27.025    40.8
# 0 t/m 4 jaar|2023            245.00   399.000   889.0
# 15 t/m 19 jaar|2023          285.00   442.000   989.0
# 20 t/m 44 jaar|2023         1640.00  2835.750  6768.0
# 45 t/m 64 jaar|2023         1205.00  1866.500  4004.0
# 5 t/m 14 jaar|2023           528.00   845.500  1738.0
# 65 t/m 79 jaar|2023          498.00   799.750  2343.0
# 80 jaar en ouder|2023        144.00   225.500   750.0

# %% [markdown]
# We will not get into it today as it goes beyond the basics we want to cover, but keep in mind that `groupby` allows you to not only call generic functions (like `sum` or `describe`), but also your own functions. This opens the door for virtually any kind of transformation and aggregation possible.
